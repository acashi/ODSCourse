# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = (i for i in range(1, 1000000002) if (i % 3 == 0) & (str(i)[-1] != '4') & (str(i)[-1] != '7'))
sum (i)

# %%
133333333466666670
# Out:
# 133333333466666670

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('input_file.txt') as file:
    text = file.readlines()

# %%
arr = []

# %%
for i in text:
    arr.append(i.split())

# %%
with open('output_file.txt', 'w') as file:
    pass

# %%
with open('input_file.txt') as file:
    text = file.readlines()
for i in arr:
    with open('output_file.txt', 'a') as file:
        file.write(str((eval(i[1] + i[0] + i[2])))+',')

# %%
'JBOljrfkrfjgikenfjerkrkvkfKUGlknc'[13:27+1]
# Out:
# 'kenfjerkrkvkfKU'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open ('import_file_2_1.txt') as file:
    first_text = file.readlines()
with open ('import_file_2_2.txt') as file:
    secont_text = file.readlines()
    
for i in range(len(first_text)):
    p, n = secont_text[i].split()
    with open ('out_file.txt', 'a') as file:
        file.write(first_text[i][int(p):int(n)+1] + ' ')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import json

# %%
periodic_table = json.load(open('periodic_table.json'))

# %%
with open ('import_file_3.txt') as file:
    file3 = file.read()
for i in periodic_table.keys():
    if len(i) < 2: 
        continue
    else: 
        file3 = file3.replace(i, periodic_table[i])
for i in periodic_table.keys():
    file3 = file3.replace(i, periodic_table[i])
with open ('out_file3.txt', 'w') as file:
    file.write(file3)
